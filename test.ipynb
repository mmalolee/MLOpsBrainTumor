# %%
from PIL import Image
from src.brain_tumor_ops.configs.paths import PathsConfig

# %%
paths = PathsConfig()
img_path = paths.source_raw_testing_data_dir / "glioma" / "Te-gl_4.jpg"
img_path
# Out:
# PosixPath('/home/mikolajmalolepszy/Desktop/Projects/BrainTumorOps/data/raw/Testing/glioma/Te-gl_4.jpg')

# %%
with Image.open(img_path) as img:
    img = img.convert("RGB")
    print(img.)
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7F9B0854FC10>
